# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
music_data = pd.read_csv("music-sales.csv")
X= music_data.drop(columns="genre")
y = music_data["genre"]
X
model = DecisionTreeClassifier()
model.fit(X,y)
predictions = model.predict([ [1,21, 1], [3,22, 0] ])
predictions
# Out:
# C:\Users\agran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'HipHop'], dtype=object)

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

x = np.array([[1],[2],[3],[4],[5]])
y = np.array([3,4,2,5,6])

model = LinearRegression()
model.fit(x,y)

print("Coefficient:", model.coef_)
print("Intercept:", model.intercept_)
print("Prediction for x=6:", model.predict([[6]]))
# Out:
# Coefficient: [0.7]
# Intercept: 1.8999999999999995
# Prediction for x=6: [6.1]

# %%
import nltk
from nltk.sentiment import SentimentIntensityAnalyzer

nltk.download('vader_lexicon')

text = "I love learning Artificial Intelligence, it's amazing!"

sia = SentimentIntensityAnalyzer()
score = sia.polarity_scores(text)

print("Sentiment Scores:", score)
# Out:
# Sentiment Scores: {'neg': 0.0, 'neu': 0.208, 'pos': 0.792, 'compound': 0.908}
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\agran\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

music_data = pd.read_csv("music-sales.csv")
X= music_data.drop(columns="genre")
y = music_data["genre"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)

model = DecisionTreeClassifier()
model.fit(X_train, y_train)
predictions = model.predict(X_test)

score = accuracy_score(y_test, predictions)
score
# Out:
# 1.0

# %%
#saving model in a file
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
import joblib

music_data = pd.read_csv("music-sales.csv")
X= music_data.drop(columns="genre")
y = music_data["genre"]

model = DecisionTreeClassifier()
model.fit(X,y)

joblib.dump(model, 'music-recommender.joblib')
joblib.load("music-recommender.joblib")
predictions = model.predict([ [1,21, 1], [3,22, 0] ])
predictions
# Out:
# C:\Users\agran\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(
# array(['HipHop', 'Dance'], dtype=object)

# %%
#visualising decision trees
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

music_data = pd.read_csv("music-sales.csv")
X= music_data.drop(columns="genre")
y = music_data["genre"]

model = DecisionTreeClassifier()
model.fit(X,y)

tree.export_graphviz(model, out_file='music-recommender.dot', 
                  feature_names=["",'age','gender'],
                  class_names=sorted(y.unique()),
                  label='all',
                  rounded=True,
                  filled=True)
